# %%
from train import *
from matplotlib import pyplot as plt

dataset_train = create_dataset(
    "temp",
    root="../temp",
    split="train",
    is_training=True,
    class_map=None,
    download=False,
    batch_size=None,
    seed=42,
    repeats=0,
)

loader_train = create_loader(
    dataset_train,
    input_size=(3,224,224),
    batch_size=2,
    mean=(0,0,0),
    std=(1,1,1),
)


for batch_idx, (input, target) in enumerate(loader_train):

    print(input[0].cpu().numpy().shape)
    print(target)
    for i in input:
        plt.imshow(i.cpu().numpy().transpose(1,2,0))
        plt.title('my img')
        plt.show() 
    break
# Out:
# ../temp/train
# temp
# {'ambulance': 0, 'firefighter': 1, 'other': 2, 'police': 3}
# (3, 224, 224)
# tensor([0, 0], device='cuda:0')

# %%
from torchvision.models.feature_extraction import get_graph_node_names, create_feature_extractor
import timm

model = timm.create_model('mixnet_s', exportable=True, num_classes=4)
nodes, _ = get_graph_node_names(model)
nodes
# Out:
# ['x',
#  'conv_stem',
#  'bn1.getattr',
#  'bn1.eq',
#  'bn1.getattr_1',
#  'bn1._assert',
#  'bn1.bn1_weight',
#  'bn1.bn1_bias',
#  'bn1.batch_norm',
#  'bn1.drop',
#  'bn1.act',
#  'blocks.0.0.conv_dw',
#  'blocks.0.0.bn1.getattr',
#  'blocks.0.0.bn1.eq',
#  'blocks.0.0.bn1.getattr_1',
#  'blocks.0.0.bn1._assert',
#  'blocks.0.0.bn1.blocks_0_0_bn1_weight',
#  'blocks.0.0.bn1.blocks_0_0_bn1_bias',
#  'blocks.0.0.bn1.batch_norm',
#  'blocks.0.0.bn1.drop',
#  'blocks.0.0.bn1.act',
#  'blocks.0.0.se',
#  'blocks.0.0.conv_pw',
#  'blocks.0.0.bn2.getattr',
#  'blocks.0.0.bn2.eq',
#  'blocks.0.0.bn2.getattr_1',
#  'blocks.0.0.bn2._assert',
#  'blocks.0.0.bn2.blocks_0_0_bn2_weight',
#  'blocks.0.0.bn2.blocks_0_0_bn2_bias',
#  'blocks.0.0.bn2.batch_norm',
#  'blocks.0.0.bn2.drop',
#  'blocks.0.0.bn2.act',
#  'blocks.0.0.drop_path',
#  'blocks.0.0.add',
#  'blocks.1.0.conv_pw.split',
#  'blocks.1.0.conv_pw.getitem',
#  'blocks.1.0.conv_pw.0',
#  'blocks.1.0.conv_pw.getitem_1',
#  'blocks.1.0.conv_pw.1',
#  'blocks.1.0.conv_pw.cat',
#  'blocks.1.0.bn1.getattr',
#  'blocks.1.0.bn1.eq',
#  'blocks.1.0.bn1.getattr_1',
#  'blocks.1.0.bn1._assert',
#  'blocks.1.0.bn1.blocks_1_0_bn1_weight',
#  'blocks.1.0.bn1.blocks_1_0_bn1_bias',
#  'blocks.1.0.bn1.batch_norm',
#  'blocks.1.0.bn1.drop',
#  'blocks.1.0.bn1.act',
#  'blocks.1.0.conv_dw',
#  'blocks.1.0.bn2.getattr',
#  'blocks.1.0.bn2.eq',
#  'blocks.1.0.bn2.getattr_1',
#  'blocks.1.0.bn2._assert',
#  'blocks.1.0.bn2.blocks_1_0_bn2_weight',
#  'blocks.1.0.bn2.blocks_1_0_bn2_bias',
#  'blocks.1.0.bn2.batch_norm',
#  'blocks.1.0.bn2.drop',
#  'blocks.1.0.bn2.act',
#  'blocks.1.0.se',
#  'blocks.1.0.conv_pwl.split',
#  'blocks.1.0.conv_pwl.getitem',
#  'blocks.1.0.conv_pwl.0',
#  'blocks.1.0.conv_pwl.getitem_1',
#  'blocks.1.0.conv_pwl.1',
#  'blocks.1.0.conv_pwl.cat',
#  'blocks.1.0.bn3.getattr',
#  'blocks.1.0.bn3.eq',
#  'blocks.1.0.bn3.getattr_1',
#  'blocks.1.0.bn3._assert',
#  'blocks.1.0.bn3.blocks_1_0_bn3_weight',
#  'blocks.1.0.bn3.blocks_1_0_bn3_bias',
#  'blocks.1.0.bn3.batch_norm',
#  'blocks.1.0.bn3.drop',
#  'blocks.1.0.bn3.act',
#  'blocks.1.1.conv_pw.split',
#  'blocks.1.1.conv_pw.getitem',
#  'blocks.1.1.conv_pw.0',
#  'blocks.1.1.conv_pw.getitem_1',
#  'blocks.1.1.conv_pw.1',
#  'blocks.1.1.conv_pw.cat',
#  'blocks.1.1.bn1.getattr',
#  'blocks.1.1.bn1.eq',
#  'blocks.1.1.bn1.getattr_1',
#  'blocks.1.1.bn1._assert',
#  'blocks.1.1.bn1.blocks_1_1_bn1_weight',
#  'blocks.1.1.bn1.blocks_1_1_bn1_bias',
#  'blocks.1.1.bn1.batch_norm',
#  'blocks.1.1.bn1.drop',
#  'blocks.1.1.bn1.act',
#  'blocks.1.1.conv_dw',
#  'blocks.1.1.bn2.getattr',
#  'blocks.1.1.bn2.eq',
#  'blocks.1.1.bn2.getattr_1',
#  'blocks.1.1.bn2._assert',
#  'blocks.1.1.bn2.blocks_1_1_bn2_weight',
#  'blocks.1.1.bn2.blocks_1_1_bn2_bias',
#  'blocks.1.1.bn2.batch_norm',
#  'blocks.1.1.bn2.drop',
#  'blocks.1.1.bn2.act',
#  'blocks.1.1.se',
#  'blocks.1.1.conv_pwl.split',
#  'blocks.1.1.conv_pwl.getitem',
#  'blocks.1.1.conv_pwl.0',
#  'blocks.1.1.conv_pwl.getitem_1',
#  'blocks.1.1.conv_pwl.1',
#  'blocks.1.1.conv_pwl.cat',
#  'blocks.1.1.bn3.getattr',
#  'blocks.1.1.bn3.eq',
#  'blocks.1.1.bn3.getattr_1',
#  'blocks.1.1.bn3._assert',
#  'blocks.1.1.bn3.blocks_1_1_bn3_weight',
#  'blocks.1.1.bn3.blocks_1_1_bn3_bias',
#  'blocks.1.1.bn3.batch_norm',
#  'blocks.1.1.bn3.drop',
#  'blocks.1.1.bn3.act',
#  'blocks.1.1.drop_path',
#  'blocks.1.1.add',
#  'blocks.2.0.conv_pw',
#  'blocks.2.0.bn1.getattr',
#  'blocks.2.0.bn1.eq',
#  'blocks.2.0.bn1.getattr_1',
#  'blocks.2.0.bn1._assert',
#  'blocks.2.0.bn1.blocks_2_0_bn1_weight',
#  'blocks.2.0.bn1.blocks_2_0_bn1_bias',
#  'blocks.2.0.bn1.batch_norm',
#  'blocks.2.0.bn1.drop',
#  'blocks.2.0.bn1.act',
#  'blocks.2.0.conv_dw.split',
#  'blocks.2.0.conv_dw.getitem',
#  'blocks.2.0.conv_dw.0',
#  'blocks.2.0.conv_dw.getitem_1',
#  'blocks.2.0.conv_dw.1',
#  'blocks.2.0.conv_dw.getitem_2',
#  'blocks.2.0.conv_dw.2',
#  'blocks.2.0.conv_dw.cat',
#  'blocks.2.0.bn2.getattr',
#  'blocks.2.0.bn2.eq',
#  'blocks.2.0.bn2.getattr_1',
#  'blocks.2.0.bn2._assert',
#  'blocks.2.0.bn2.blocks_2_0_bn2_weight',
#  'blocks.2.0.bn2.blocks_2_0_bn2_bias',
#  'blocks.2.0.bn2.batch_norm',
#  'blocks.2.0.bn2.drop',
#  'blocks.2.0.bn2.act',
#  'blocks.2.0.se.mean',
#  'blocks.2.0.se.conv_reduce',
#  'blocks.2.0.se.act1',
#  'blocks.2.0.se.conv_expand',
#  'blocks.2.0.se.gate',
#  'blocks.2.0.se.mul',
#  'blocks.2.0.conv_pwl',
#  'blocks.2.0.bn3.getattr',
#  'blocks.2.0.bn3.eq',
#  'blocks.2.0.bn3.getattr_1',
#  'blocks.2.0.bn3._assert',
#  'blocks.2.0.bn3.blocks_2_0_bn3_weight',
#  'blocks.2.0.bn3.blocks_2_0_bn3_bias',
#  'blocks.2.0.bn3.batch_norm',
#  'blocks.2.0.bn3.drop',
#  'blocks.2.0.bn3.act',
#  'blocks.2.1.conv_pw.split',
#  'blocks.2.1.conv_pw.getitem',
#  'blocks.2.1.conv_pw.0',
#  'blocks.2.1.conv_pw.getitem_1',
#  'blocks.2.1.conv_pw.1',
#  'blocks.2.1.conv_pw.cat',
#  'blocks.2.1.bn1.getattr',
#  'blocks.2.1.bn1.eq',
#  'blocks.2.1.bn1.getattr_1',
#  'blocks.2.1.bn1._assert',
#  'blocks.2.1.bn1.blocks_2_1_bn1_weight',
#  'blocks.2.1.bn1.blocks_2_1_bn1_bias',
#  'blocks.2.1.bn1.batch_norm',
#  'blocks.2.1.bn1.drop',
#  'blocks.2.1.bn1.act',
#  'blocks.2.1.conv_dw.split',
#  'blocks.2.1.conv_dw.getitem',
#  'blocks.2.1.conv_dw.0',
#  'blocks.2.1.conv_dw.getitem_1',
#  'blocks.2.1.conv_dw.1',
#  'blocks.2.1.conv_dw.cat',
#  'blocks.2.1.bn2.getattr',
#  'blocks.2.1.bn2.eq',
#  'blocks.2.1.bn2.getattr_1',
#  'blocks.2.1.bn2._assert',
#  'blocks.2.1.bn2.blocks_2_1_bn2_weight',
#  'blocks.2.1.bn2.blocks_2_1_bn2_bias',
#  'blocks.2.1.bn2.batch_norm',
#  'blocks.2.1.bn2.drop',
#  'blocks.2.1.bn2.act',
#  'blocks.2.1.se.mean',
#  'blocks.2.1.se.conv_reduce',
#  'blocks.2.1.se.act1',
#  'blocks.2.1.se.conv_expand',
#  'blocks.2.1.se.gate',
#  'blocks.2.1.se.mul',
#  'blocks.2.1.conv_pwl.split',
#  'blocks.2.1.conv_pwl.getitem',
#  'blocks.2.1.conv_pwl.0',
#  'blocks.2.1.conv_pwl.getitem_1',
#  'blocks.2.1.conv_pwl.1',
#  'blocks.2.1.conv_pwl.cat',
#  'blocks.2.1.bn3.getattr',
#  'blocks.2.1.bn3.eq',
#  'blocks.2.1.bn3.getattr_1',
#  'blocks.2.1.bn3._assert',
#  'blocks.2.1.bn3.blocks_2_1_bn3_weight',
#  'blocks.2.1.bn3.blocks_2_1_bn3_bias',
#  'blocks.2.1.bn3.batch_norm',
#  'blocks.2.1.bn3.drop',
#  'blocks.2.1.bn3.act',
#  'blocks.2.1.drop_path',
#  'blocks.2.1.add',
#  'blocks.2.2.conv_pw.split',
#  'blocks.2.2.conv_pw.getitem',
#  'blocks.2.2.conv_pw.0',
#  'blocks.2.2.conv_pw.getitem_1',
#  'blocks.2.2.conv_pw.1',
#  'blocks.2.2.conv_pw.cat',
#  'blocks.2.2.bn1.getattr',
#  'blocks.2.2.bn1.eq',
#  'blocks.2.2.bn1.getattr_1',
#  'blocks.2.2.bn1._assert',
#  'blocks.2.2.bn1.blocks_2_2_bn1_weight',
#  'blocks.2.2.bn1.blocks_2_2_bn1_bias',
#  'blocks.2.2.bn1.batch_norm',
#  'blocks.2.2.bn1.drop',
#  'blocks.2.2.bn1.act',
#  'blocks.2.2.conv_dw.split',
#  'blocks.2.2.conv_dw.getitem',
#  'blocks.2.2.conv_dw.0',
#  'blocks.2.2.conv_dw.getitem_1',
#  'blocks.2.2.conv_dw.1',
#  'blocks.2.2.conv_dw.cat',
#  'blocks.2.2.bn2.getattr',
#  'blocks.2.2.bn2.eq',
#  'blocks.2.2.bn2.getattr_1',
#  'blocks.2.2.bn2._assert',
#  'blocks.2.2.bn2.blocks_2_2_bn2_weight',
#  'blocks.2.2.bn2.blocks_2_2_bn2_bias',
#  'blocks.2.2.bn2.batch_norm',
#  'blocks.2.2.bn2.drop',
#  'blocks.2.2.bn2.act',
#  'blocks.2.2.se.mean',
#  'blocks.2.2.se.conv_reduce',
#  'blocks.2.2.se.act1',
#  'blocks.2.2.se.conv_expand',
#  'blocks.2.2.se.gate',
#  'blocks.2.2.se.mul',
#  'blocks.2.2.conv_pwl.split',
#  'blocks.2.2.conv_pwl.getitem',
#  'blocks.2.2.conv_pwl.0',
#  'blocks.2.2.conv_pwl.getitem_1',
#  'blocks.2.2.conv_pwl.1',
#  'blocks.2.2.conv_pwl.cat',
#  'blocks.2.2.bn3.getattr',
#  'blocks.2.2.bn3.eq',
#  'blocks.2.2.bn3.getattr_1',
#  'blocks.2.2.bn3._assert',
#  'blocks.2.2.bn3.blocks_2_2_bn3_weight',
#  'blocks.2.2.bn3.blocks_2_2_bn3_bias',
#  'blocks.2.2.bn3.batch_norm',
#  'blocks.2.2.bn3.drop',
#  'blocks.2.2.bn3.act',
#  'blocks.2.2.drop_path',
#  'blocks.2.2.add',
#  'blocks.2.3.conv_pw.split',
#  'blocks.2.3.conv_pw.getitem',
#  'blocks.2.3.conv_pw.0',
#  'blocks.2.3.conv_pw.getitem_1',
#  'blocks.2.3.conv_pw.1',
#  'blocks.2.3.conv_pw.cat',
#  'blocks.2.3.bn1.getattr',
#  'blocks.2.3.bn1.eq',
#  'blocks.2.3.bn1.getattr_1',
#  'blocks.2.3.bn1._assert',
#  'blocks.2.3.bn1.blocks_2_3_bn1_weight',
#  'blocks.2.3.bn1.blocks_2_3_bn1_bias',
#  'blocks.2.3.bn1.batch_norm',
#  'blocks.2.3.bn1.drop',
#  'blocks.2.3.bn1.act',
#  'blocks.2.3.conv_dw.split',
#  'blocks.2.3.conv_dw.getitem',
#  'blocks.2.3.conv_dw.0',
#  'blocks.2.3.conv_dw.getitem_1',
#  'blocks.2.3.conv_dw.1',
#  'blocks.2.3.conv_dw.cat',
#  'blocks.2.3.bn2.getattr',
#  'blocks.2.3.bn2.eq',
#  'blocks.2.3.bn2.getattr_1',
#  'blocks.2.3.bn2._assert',
#  'blocks.2.3.bn2.blocks_2_3_bn2_weight',
#  'blocks.2.3.bn2.blocks_2_3_bn2_bias',
#  'blocks.2.3.bn2.batch_norm',
#  'blocks.2.3.bn2.drop',
#  'blocks.2.3.bn2.act',
#  'blocks.2.3.se.mean',
#  'blocks.2.3.se.conv_reduce',
#  'blocks.2.3.se.act1',
#  'blocks.2.3.se.conv_expand',
#  'blocks.2.3.se.gate',
#  'blocks.2.3.se.mul',
#  'blocks.2.3.conv_pwl.split',
#  'blocks.2.3.conv_pwl.getitem',
#  'blocks.2.3.conv_pwl.0',
#  'blocks.2.3.conv_pwl.getitem_1',
#  'blocks.2.3.conv_pwl.1',
#  'blocks.2.3.conv_pwl.cat',
#  'blocks.2.3.bn3.getattr',
#  'blocks.2.3.bn3.eq',
#  'blocks.2.3.bn3.getattr_1',
#  'blocks.2.3.bn3._assert',
#  'blocks.2.3.bn3.blocks_2_3_bn3_weight',
#  'blocks.2.3.bn3.blocks_2_3_bn3_bias',
#  'blocks.2.3.bn3.batch_norm',
#  'blocks.2.3.bn3.drop',
#  'blocks.2.3.bn3.act',
#  'blocks.2.3.drop_path',
#  'blocks.2.3.add',
#  'blocks.3.0.conv_pw',
#  'blocks.3.0.bn1.getattr',
#  'blocks.3.0.bn1.eq',
#  'blocks.3.0.bn1.getattr_1',
#  'blocks.3.0.bn1._assert',
#  'blocks.3.0.bn1.blocks_3_0_bn1_weight',
#  'blocks.3.0.bn1.blocks_3_0_bn1_bias',
#  'blocks.3.0.bn1.batch_norm',
#  'blocks.3.0.bn1.drop',
#  'blocks.3.0.bn1.act',
#  'blocks.3.0.conv_dw.split',
#  'blocks.3.0.conv_dw.getitem',
#  'blocks.3.0.conv_dw.0',
#  'blocks.3.0.conv_dw.getitem_1',
#  'blocks.3.0.conv_dw.1',
#  'blocks.3.0.conv_dw.getitem_2',
#  'blocks.3.0.conv_dw.2',
#  'blocks.3.0.conv_dw.cat',
#  'blocks.3.0.bn2.getattr',
#  'blocks.3.0.bn2.eq',
#  'blocks.3.0.bn2.getattr_1',
#  'blocks.3.0.bn2._assert',
#  'blocks.3.0.bn2.blocks_3_0_bn2_weight',
#  'blocks.3.0.bn2.blocks_3_0_bn2_bias',
#  'blocks.3.0.bn2.batch_norm',
#  'blocks.3.0.bn2.drop',
#  'blocks.3.0.bn2.act',
#  'blocks.3.0.se.mean',
#  'blocks.3.0.se.conv_reduce',
#  'blocks.3.0.se.act1',
#  'blocks.3.0.se.conv_expand',
#  'blocks.3.0.se.gate',
#  'blocks.3.0.se.mul',
#  'blocks.3.0.conv_pwl.split',
#  'blocks.3.0.conv_pwl.getitem',
#  'blocks.3.0.conv_pwl.0',
#  'blocks.3.0.conv_pwl.getitem_1',
#  'blocks.3.0.conv_pwl.1',
#  'blocks.3.0.conv_pwl.cat',
#  'blocks.3.0.bn3.getattr',
#  'blocks.3.0.bn3.eq',
#  'blocks.3.0.bn3.getattr_1',
#  'blocks.3.0.bn3._assert',
#  'blocks.3.0.bn3.blocks_3_0_bn3_weight',
#  'blocks.3.0.bn3.blocks_3_0_bn3_bias',
#  'blocks.3.0.bn3.batch_norm',
#  'blocks.3.0.bn3.drop',
#  'blocks.3.0.bn3.act',
#  'blocks.3.1.conv_pw',
#  'blocks.3.1.bn1.getattr',
#  'blocks.3.1.bn1.eq',
#  'blocks.3.1.bn1.getattr_1',
#  'blocks.3.1.bn1._assert',
#  'blocks.3.1.bn1.blocks_3_1_bn1_weight',
#  'blocks.3.1.bn1.blocks_3_1_bn1_bias',
#  'blocks.3.1.bn1.batch_norm',
#  'blocks.3.1.bn1.drop',
#  'blocks.3.1.bn1.act',
#  'blocks.3.1.conv_dw.split',
#  'blocks.3.1.conv_dw.getitem',
#  'blocks.3.1.conv_dw.0',
#  'blocks.3.1.conv_dw.getitem_1',
#  'blocks.3.1.conv_dw.1',
#  'blocks.3.1.conv_dw.cat',
#  'blocks.3.1.bn2.getattr',
#  'blocks.3.1.bn2.eq',
#  'blocks.3.1.bn2.getattr_1',
#  'blocks.3.1.bn2._assert',
#  'blocks.3.1.bn2.blocks_3_1_bn2_weight',
#  'blocks.3.1.bn2.blocks_3_1_bn2_bias',
#  'blocks.3.1.bn2.batch_norm',
#  'blocks.3.1.bn2.drop',
#  'blocks.3.1.bn2.act',
#  'blocks.3.1.se.mean',
#  'blocks.3.1.se.conv_reduce',
#  'blocks.3.1.se.act1',
#  'blocks.3.1.se.conv_expand',
#  'blocks.3.1.se.gate',
#  'blocks.3.1.se.mul',
#  'blocks.3.1.conv_pwl.split',
#  'blocks.3.1.conv_pwl.getitem',
#  'blocks.3.1.conv_pwl.0',
#  'blocks.3.1.conv_pwl.getitem_1',
#  'blocks.3.1.conv_pwl.1',
#  'blocks.3.1.conv_pwl.cat',
#  'blocks.3.1.bn3.getattr',
#  'blocks.3.1.bn3.eq',
#  'blocks.3.1.bn3.getattr_1',
#  'blocks.3.1.bn3._assert',
#  'blocks.3.1.bn3.blocks_3_1_bn3_weight',
#  'blocks.3.1.bn3.blocks_3_1_bn3_bias',
#  'blocks.3.1.bn3.batch_norm',
#  'blocks.3.1.bn3.drop',
#  'blocks.3.1.bn3.act',
#  'blocks.3.1.drop_path',
#  'blocks.3.1.add',
#  'blocks.3.2.conv_pw',
#  'blocks.3.2.bn1.getattr',
#  'blocks.3.2.bn1.eq',
#  'blocks.3.2.bn1.getattr_1',
#  'blocks.3.2.bn1._assert',
#  'blocks.3.2.bn1.blocks_3_2_bn1_weight',
#  'blocks.3.2.bn1.blocks_3_2_bn1_bias',
#  'blocks.3.2.bn1.batch_norm',
#  'blocks.3.2.bn1.drop',
#  'blocks.3.2.bn1.act',
#  'blocks.3.2.conv_dw.split',
#  'blocks.3.2.conv_dw.getitem',
#  'blocks.3.2.conv_dw.0',
#  'blocks.3.2.conv_dw.getitem_1',
#  'blocks.3.2.conv_dw.1',
#  'blocks.3.2.conv_dw.cat',
#  'blocks.3.2.bn2.getattr',
#  'blocks.3.2.bn2.eq',
#  'blocks.3.2.bn2.getattr_1',
#  'blocks.3.2.bn2._assert',
#  'blocks.3.2.bn2.blocks_3_2_bn2_weight',
#  'blocks.3.2.bn2.blocks_3_2_bn2_bias',
#  'blocks.3.2.bn2.batch_norm',
#  'blocks.3.2.bn2.drop',
#  'blocks.3.2.bn2.act',
#  'blocks.3.2.se.mean',
#  'blocks.3.2.se.conv_reduce',
#  'blocks.3.2.se.act1',
#  'blocks.3.2.se.conv_expand',
#  'blocks.3.2.se.gate',
#  'blocks.3.2.se.mul',
#  'blocks.3.2.conv_pwl.split',
#  'blocks.3.2.conv_pwl.getitem',
#  'blocks.3.2.conv_pwl.0',
#  'blocks.3.2.conv_pwl.getitem_1',
#  'blocks.3.2.conv_pwl.1',
#  'blocks.3.2.conv_pwl.cat',
#  'blocks.3.2.bn3.getattr',
#  'blocks.3.2.bn3.eq',
#  'blocks.3.2.bn3.getattr_1',
#  'blocks.3.2.bn3._assert',
#  'blocks.3.2.bn3.blocks_3_2_bn3_weight',
#  'blocks.3.2.bn3.blocks_3_2_bn3_bias',
#  'blocks.3.2.bn3.batch_norm',
#  'blocks.3.2.bn3.drop',
#  'blocks.3.2.bn3.act',
#  'blocks.3.2.drop_path',
#  'blocks.3.2.add',
#  'blocks.4.0.conv_pw.split',
#  'blocks.4.0.conv_pw.getitem',
#  'blocks.4.0.conv_pw.0',
#  'blocks.4.0.conv_pw.getitem_1',
#  'blocks.4.0.conv_pw.1',
#  'blocks.4.0.conv_pw.cat',
#  'blocks.4.0.bn1.getattr',
#  'blocks.4.0.bn1.eq',
#  'blocks.4.0.bn1.getattr_1',
#  'blocks.4.0.bn1._assert',
#  'blocks.4.0.bn1.blocks_4_0_bn1_weight',
#  'blocks.4.0.bn1.blocks_4_0_bn1_bias',
#  'blocks.4.0.bn1.batch_norm',
#  'blocks.4.0.bn1.drop',
#  'blocks.4.0.bn1.act',
#  'blocks.4.0.conv_dw.split',
#  'blocks.4.0.conv_dw.getitem',
#  'blocks.4.0.conv_dw.0',
#  'blocks.4.0.conv_dw.getitem_1',
#  'blocks.4.0.conv_dw.1',
#  'blocks.4.0.conv_dw.getitem_2',
#  'blocks.4.0.conv_dw.2',
#  'blocks.4.0.conv_dw.cat',
#  'blocks.4.0.bn2.getattr',
#  'blocks.4.0.bn2.eq',
#  'blocks.4.0.bn2.getattr_1',
#  'blocks.4.0.bn2._assert',
#  'blocks.4.0.bn2.blocks_4_0_bn2_weight',
#  'blocks.4.0.bn2.blocks_4_0_bn2_bias',
#  'blocks.4.0.bn2.batch_norm',
#  'blocks.4.0.bn2.drop',
#  'blocks.4.0.bn2.act',
#  'blocks.4.0.se.mean',
#  'blocks.4.0.se.conv_reduce',
#  'blocks.4.0.se.act1',
#  'blocks.4.0.se.conv_expand',
#  'blocks.4.0.se.gate',
#  'blocks.4.0.se.mul',
#  'blocks.4.0.conv_pwl.split',
#  'blocks.4.0.conv_pwl.getitem',
#  'blocks.4.0.conv_pwl.0',
#  'blocks.4.0.conv_pwl.getitem_1',
#  'blocks.4.0.conv_pwl.1',
#  'blocks.4.0.conv_pwl.cat',
#  'blocks.4.0.bn3.getattr',
#  'blocks.4.0.bn3.eq',
#  'blocks.4.0.bn3.getattr_1',
#  'blocks.4.0.bn3._assert',
#  'blocks.4.0.bn3.blocks_4_0_bn3_weight',
#  'blocks.4.0.bn3.blocks_4_0_bn3_bias',
#  'blocks.4.0.bn3.batch_norm',
#  'blocks.4.0.bn3.drop',
#  'blocks.4.0.bn3.act',
#  'blocks.4.1.conv_pw.split',
#  'blocks.4.1.conv_pw.getitem',
#  'blocks.4.1.conv_pw.0',
#  'blocks.4.1.conv_pw.getitem_1',
#  'blocks.4.1.conv_pw.1',
#  'blocks.4.1.conv_pw.cat',
#  'blocks.4.1.bn1.getattr',
#  'blocks.4.1.bn1.eq',
#  'blocks.4.1.bn1.getattr_1',
#  'blocks.4.1.bn1._assert',
#  'blocks.4.1.bn1.blocks_4_1_bn1_weight',
#  'blocks.4.1.bn1.blocks_4_1_bn1_bias',
#  'blocks.4.1.bn1.batch_norm',
#  'blocks.4.1.bn1.drop',
#  'blocks.4.1.bn1.act',
#  'blocks.4.1.conv_dw.split',
#  'blocks.4.1.conv_dw.getitem',
#  'blocks.4.1.conv_dw.0',
#  'blocks.4.1.conv_dw.getitem_1',
#  'blocks.4.1.conv_dw.1',
#  'blocks.4.1.conv_dw.getitem_2',
#  'blocks.4.1.conv_dw.2',
#  'blocks.4.1.conv_dw.getitem_3',
#  'blocks.4.1.conv_dw.3',
#  'blocks.4.1.conv_dw.cat',
#  'blocks.4.1.bn2.getattr',
#  'blocks.4.1.bn2.eq',
#  'blocks.4.1.bn2.getattr_1',
#  'blocks.4.1.bn2._assert',
#  'blocks.4.1.bn2.blocks_4_1_bn2_weight',
#  'blocks.4.1.bn2.blocks_4_1_bn2_bias',
#  'blocks.4.1.bn2.batch_norm',
#  'blocks.4.1.bn2.drop',
#  'blocks.4.1.bn2.act',
#  'blocks.4.1.se.mean',
#  'blocks.4.1.se.conv_reduce',
#  'blocks.4.1.se.act1',
#  'blocks.4.1.se.conv_expand',
#  'blocks.4.1.se.gate',
#  'blocks.4.1.se.mul',
#  'blocks.4.1.conv_pwl.split',
#  'blocks.4.1.conv_pwl.getitem',
#  'blocks.4.1.conv_pwl.0',
#  'blocks.4.1.conv_pwl.getitem_1',
#  'blocks.4.1.conv_pwl.1',
#  'blocks.4.1.conv_pwl.cat',
#  'blocks.4.1.bn3.getattr',
#  'blocks.4.1.bn3.eq',
#  'blocks.4.1.bn3.getattr_1',
#  'blocks.4.1.bn3._assert',
#  'blocks.4.1.bn3.blocks_4_1_bn3_weight',
#  'blocks.4.1.bn3.blocks_4_1_bn3_bias',
#  'blocks.4.1.bn3.batch_norm',
#  'blocks.4.1.bn3.drop',
#  'blocks.4.1.bn3.act',
#  'blocks.4.1.drop_path',
#  'blocks.4.1.add',
#  'blocks.4.2.conv_pw.split',
#  'blocks.4.2.conv_pw.getitem',
#  'blocks.4.2.conv_pw.0',
#  'blocks.4.2.conv_pw.getitem_1',
#  'blocks.4.2.conv_pw.1',
#  'blocks.4.2.conv_pw.cat',
#  'blocks.4.2.bn1.getattr',
#  'blocks.4.2.bn1.eq',
#  'blocks.4.2.bn1.getattr_1',
#  'blocks.4.2.bn1._assert',
#  'blocks.4.2.bn1.blocks_4_2_bn1_weight',
#  'blocks.4.2.bn1.blocks_4_2_bn1_bias',
#  'blocks.4.2.bn1.batch_norm',
#  'blocks.4.2.bn1.drop',
#  'blocks.4.2.bn1.act',
#  'blocks.4.2.conv_dw.split',
#  'blocks.4.2.conv_dw.getitem',
#  'blocks.4.2.conv_dw.0',
#  'blocks.4.2.conv_dw.getitem_1',
#  'blocks.4.2.conv_dw.1',
#  'blocks.4.2.conv_dw.getitem_2',
#  'blocks.4.2.conv_dw.2',
#  'blocks.4.2.conv_dw.getitem_3',
#  'blocks.4.2.conv_dw.3',
#  'blocks.4.2.conv_dw.cat',
#  'blocks.4.2.bn2.getattr',
#  'blocks.4.2.bn2.eq',
#  'blocks.4.2.bn2.getattr_1',
#  'blocks.4.2.bn2._assert',
#  'blocks.4.2.bn2.blocks_4_2_bn2_weight',
#  'blocks.4.2.bn2.blocks_4_2_bn2_bias',
#  'blocks.4.2.bn2.batch_norm',
#  'blocks.4.2.bn2.drop',
#  'blocks.4.2.bn2.act',
#  'blocks.4.2.se.mean',
#  'blocks.4.2.se.conv_reduce',
#  'blocks.4.2.se.act1',
#  'blocks.4.2.se.conv_expand',
#  'blocks.4.2.se.gate',
#  'blocks.4.2.se.mul',
#  'blocks.4.2.conv_pwl.split',
#  'blocks.4.2.conv_pwl.getitem',
#  'blocks.4.2.conv_pwl.0',
#  'blocks.4.2.conv_pwl.getitem_1',
#  'blocks.4.2.conv_pwl.1',
#  'blocks.4.2.conv_pwl.cat',
#  'blocks.4.2.bn3.getattr',
#  'blocks.4.2.bn3.eq',
#  'blocks.4.2.bn3.getattr_1',
#  'blocks.4.2.bn3._assert',
#  'blocks.4.2.bn3.blocks_4_2_bn3_weight',
#  'blocks.4.2.bn3.blocks_4_2_bn3_bias',
#  'blocks.4.2.bn3.batch_norm',
#  'blocks.4.2.bn3.drop',
#  'blocks.4.2.bn3.act',
#  'blocks.4.2.drop_path',
#  'blocks.4.2.add',
#  'blocks.5.0.conv_pw',
#  'blocks.5.0.bn1.getattr',
#  'blocks.5.0.bn1.eq',
#  'blocks.5.0.bn1.getattr_1',
#  'blocks.5.0.bn1._assert',
#  'blocks.5.0.bn1.blocks_5_0_bn1_weight',
#  'blocks.5.0.bn1.blocks_5_0_bn1_bias',
#  'blocks.5.0.bn1.batch_norm',
#  'blocks.5.0.bn1.drop',
#  'blocks.5.0.bn1.act',
#  'blocks.5.0.conv_dw.split',
#  'blocks.5.0.conv_dw.getitem',
#  'blocks.5.0.conv_dw.0',
#  'blocks.5.0.conv_dw.getitem_1',
#  'blocks.5.0.conv_dw.1',
#  'blocks.5.0.conv_dw.getitem_2',
#  'blocks.5.0.conv_dw.2',
#  'blocks.5.0.conv_dw.getitem_3',
#  'blocks.5.0.conv_dw.3',
#  'blocks.5.0.conv_dw.getitem_4',
#  'blocks.5.0.conv_dw.4',
#  'blocks.5.0.conv_dw.cat',
#  'blocks.5.0.bn2.getattr',
#  'blocks.5.0.bn2.eq',
#  'blocks.5.0.bn2.getattr_1',
#  'blocks.5.0.bn2._assert',
#  'blocks.5.0.bn2.blocks_5_0_bn2_weight',
#  'blocks.5.0.bn2.blocks_5_0_bn2_bias',
#  'blocks.5.0.bn2.batch_norm',
#  'blocks.5.0.bn2.drop',
#  'blocks.5.0.bn2.act',
#  'blocks.5.0.se.mean',
#  'blocks.5.0.se.conv_reduce',
#  'blocks.5.0.se.act1',
#  'blocks.5.0.se.conv_expand',
#  'blocks.5.0.se.gate',
#  'blocks.5.0.se.mul',
#  'blocks.5.0.conv_pwl',
#  'blocks.5.0.bn3.getattr',
#  'blocks.5.0.bn3.eq',
#  'blocks.5.0.bn3.getattr_1',
#  'blocks.5.0.bn3._assert',
#  'blocks.5.0.bn3.blocks_5_0_bn3_weight',
#  'blocks.5.0.bn3.blocks_5_0_bn3_bias',
#  'blocks.5.0.bn3.batch_norm',
#  'blocks.5.0.bn3.drop',
#  'blocks.5.0.bn3.act',
#  'blocks.5.1.conv_pw',
#  'blocks.5.1.bn1.getattr',
#  'blocks.5.1.bn1.eq',
#  'blocks.5.1.bn1.getattr_1',
#  'blocks.5.1.bn1._assert',
#  'blocks.5.1.bn1.blocks_5_1_bn1_weight',
#  'blocks.5.1.bn1.blocks_5_1_bn1_bias',
#  'blocks.5.1.bn1.batch_norm',
#  'blocks.5.1.bn1.drop',
#  'blocks.5.1.bn1.act',
#  'blocks.5.1.conv_dw.split',
#  'blocks.5.1.conv_dw.getitem',
#  'blocks.5.1.conv_dw.0',
#  'blocks.5.1.conv_dw.getitem_1',
#  'blocks.5.1.conv_dw.1',
#  'blocks.5.1.conv_dw.getitem_2',
#  'blocks.5.1.conv_dw.2',
#  'blocks.5.1.conv_dw.getitem_3',
#  'blocks.5.1.conv_dw.3',
#  'blocks.5.1.conv_dw.cat',
#  'blocks.5.1.bn2.getattr',
#  'blocks.5.1.bn2.eq',
#  'blocks.5.1.bn2.getattr_1',
#  'blocks.5.1.bn2._assert',
#  'blocks.5.1.bn2.blocks_5_1_bn2_weight',
#  'blocks.5.1.bn2.blocks_5_1_bn2_bias',
#  'blocks.5.1.bn2.batch_norm',
#  'blocks.5.1.bn2.drop',
#  'blocks.5.1.bn2.act',
#  'blocks.5.1.se.mean',
#  'blocks.5.1.se.conv_reduce',
#  'blocks.5.1.se.act1',
#  'blocks.5.1.se.conv_expand',
#  'blocks.5.1.se.gate',
#  'blocks.5.1.se.mul',
#  'blocks.5.1.conv_pwl.split',
#  'blocks.5.1.conv_pwl.getitem',
#  'blocks.5.1.conv_pwl.0',
#  'blocks.5.1.conv_pwl.getitem_1',
#  'blocks.5.1.conv_pwl.1',
#  'blocks.5.1.conv_pwl.cat',
#  'blocks.5.1.bn3.getattr',
#  'blocks.5.1.bn3.eq',
#  'blocks.5.1.bn3.getattr_1',
#  'blocks.5.1.bn3._assert',
#  'blocks.5.1.bn3.blocks_5_1_bn3_weight',
#  'blocks.5.1.bn3.blocks_5_1_bn3_bias',
#  'blocks.5.1.bn3.batch_norm',
#  'blocks.5.1.bn3.drop',
#  'blocks.5.1.bn3.act',
#  'blocks.5.1.drop_path',
#  'blocks.5.1.add',
#  'blocks.5.2.conv_pw',
#  'blocks.5.2.bn1.getattr',
#  'blocks.5.2.bn1.eq',
#  'blocks.5.2.bn1.getattr_1',
#  'blocks.5.2.bn1._assert',
#  'blocks.5.2.bn1.blocks_5_2_bn1_weight',
#  'blocks.5.2.bn1.blocks_5_2_bn1_bias',
#  'blocks.5.2.bn1.batch_norm',
#  'blocks.5.2.bn1.drop',
#  'blocks.5.2.bn1.act',
#  'blocks.5.2.conv_dw.split',
#  'blocks.5.2.conv_dw.getitem',
#  'blocks.5.2.conv_dw.0',
#  'blocks.5.2.conv_dw.getitem_1',
#  'blocks.5.2.conv_dw.1',
#  'blocks.5.2.conv_dw.getitem_2',
#  'blocks.5.2.conv_dw.2',
#  'blocks.5.2.conv_dw.getitem_3',
#  'blocks.5.2.conv_dw.3',
#  'blocks.5.2.conv_dw.cat',
#  'blocks.5.2.bn2.getattr',
#  'blocks.5.2.bn2.eq',
#  'blocks.5.2.bn2.getattr_1',
#  'blocks.5.2.bn2._assert',
#  'blocks.5.2.bn2.blocks_5_2_bn2_weight',
#  'blocks.5.2.bn2.blocks_5_2_bn2_bias',
#  'blocks.5.2.bn2.batch_norm',
#  'blocks.5.2.bn2.drop',
#  'blocks.5.2.bn2.act',
#  'blocks.5.2.se.mean',
#  'blocks.5.2.se.conv_reduce',
#  'blocks.5.2.se.act1',
#  'blocks.5.2.se.conv_expand',
#  'blocks.5.2.se.gate',
#  'blocks.5.2.se.mul',
#  'blocks.5.2.conv_pwl.split',
#  'blocks.5.2.conv_pwl.getitem',
#  'blocks.5.2.conv_pwl.0',
#  'blocks.5.2.conv_pwl.getitem_1',
#  'blocks.5.2.conv_pwl.1',
#  'blocks.5.2.conv_pwl.cat',
#  'blocks.5.2.bn3.getattr',
#  'blocks.5.2.bn3.eq',
#  'blocks.5.2.bn3.getattr_1',
#  'blocks.5.2.bn3._assert',
#  'blocks.5.2.bn3.blocks_5_2_bn3_weight',
#  'blocks.5.2.bn3.blocks_5_2_bn3_bias',
#  'blocks.5.2.bn3.batch_norm',
#  'blocks.5.2.bn3.drop',
#  'blocks.5.2.bn3.act',
#  'blocks.5.2.drop_path',
#  'blocks.5.2.add',
#  'conv_head',
#  'bn2.getattr',
#  'bn2.eq',
#  'bn2.getattr_1',
#  'bn2._assert',
#  'bn2.bn2_weight',
#  'bn2.bn2_bias',
#  'bn2.batch_norm',
#  'bn2.drop',
#  'bn2.act',
#  'global_pool.pool',
#  'global_pool.flatten',
#  'classifier']

# %%
features = {'classifier': 'out'}
feature_extractor = create_feature_extractor(model, return_nodes=features)

feature_extractor
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): Module(
#     (drop): Identity()
#     (act): ReLU(inplace=True)
#   )
#   (blocks): Module(
#     (0): Module(
#       (0): Module(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Module(
#       (0): Module(
#         (conv_pw): Module(
#           (0): Conv2d(8, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(8, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): Module(
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Module(
#           (0): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (1): Module(
#         (conv_pw): Module(
#           (0): Conv2d(12, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(12, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (conv_dw): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#         (bn2): Module(
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Module(
#           (0): Conv2d(36, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(36, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (2): Module(
#       (0): Module(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#           (1): Conv2d(48, 48, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=48, bias=False)
#           (2): Conv2d(48, 48, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=48, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(144, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (1): Module(
#         (conv_pw): Module(
#           (0): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#           (1): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(240, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): Module(
#         (conv_pw): Module(
#           (0): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#           (1): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(240, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): Module(
#         (conv_pw): Module(
#           (0): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#           (1): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(240, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (3): Module(
#       (0): Module(
#         (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(80, 80, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=80, bias=False)
#           (1): Conv2d(80, 80, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=80, bias=False)
#           (2): Conv2d(80, 80, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=80, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (1): Module(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#           (1): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): Module(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#           (1): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (4): Module(
#       (0): Module(
#         (conv_pw): Module(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (1): Conv2d(160, 160, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=160, bias=False)
#           (2): Conv2d(160, 160, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=160, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(480, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(40, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (1): Module(
#         (conv_pw): Module(
#           (0): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(90, 90, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=90, bias=False)
#           (1): Conv2d(90, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=90, bias=False)
#           (2): Conv2d(90, 90, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=90, bias=False)
#           (3): Conv2d(90, 90, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=90, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(360, 60, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(60, 360, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): Module(
#         (conv_pw): Module(
#           (0): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(90, 90, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=90, bias=False)
#           (1): Conv2d(90, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=90, bias=False)
#           (2): Conv2d(90, 90, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=90, bias=False)
#           (3): Conv2d(90, 90, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=90, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(360, 60, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(60, 360, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (5): Module(
#       (0): Module(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#           (2): Conv2d(144, 144, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=144, bias=False)
#           (3): Conv2d(144, 144, kernel_size=(9, 9), stride=(2, 2), padding=(4, 4), groups=144, bias=False)
#           (4): Conv2d(144, 144, kernel_size=(11, 11), stride=(2, 2), padding=(5, 5), groups=144, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(720, 60, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(60, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (1): Module(
#         (conv_pw): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(300, 300, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=300, bias=False)
#           (1): Conv2d(300, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=300, bias=False)
#           (2): Conv2d(300, 300, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=300, bias=False)
#           (3): Conv2d(300, 300, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=300, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(1200, 100, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(100, 1200, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): Module(
#         (conv_pw): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Module(
#           (0): Conv2d(300, 300, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=300, bias=False)
#           (1): Conv2d(300, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=300, bias=False)
#           (2): Conv2d(300, 300, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=300, bias=False)
#           (3): Conv2d(300, 300, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=300, bias=False)
#         )
#         (bn2): Module(
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Module(
#           (conv_reduce): Conv2d(1200, 100, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(100, 1200, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Module(
#           (0): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): Module(
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#   )
#   (conv_head): Conv2d(200, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): Module(
#     (drop): Identity()
#     (act): ReLU(inplace=True)
#   )
#   (global_pool): Module(
#     (pool): AdaptiveAvgPool2d(output_size=1)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (classifier): Linear(in_features=1536, out_features=4, bias=True)
# )
